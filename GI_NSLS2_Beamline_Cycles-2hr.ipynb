# %%
import numpy as np
#matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import glob
import time
plt.rcParams["figure.figsize"] = (3,3)

print (time.ctime())
# Out:
# Tue Sep 28 23:31:36 2021

# %%
# read a data file, store all data in arrays

file = "../../CSV/Beamline_Cycles-2hr_W0028_H07-210806-140732-66.csv"


print (file)
time.ctime()

data=np.loadtxt(file, dtype= int, delimiter=",", usecols = (0,1,2,3))

x   = data[:, 0]
y   = data[:, 1]
toa   = data[:, 2]
tot   = data[:, 3]

toa = toa / 4096*25*1e-9

f_x = open("../../data/beamline/Beamline_Cycles-2hr_W0028_H07-210806-140732-66/x.npz", "wb")
f_y = open("../../data/beamline/Beamline_Cycles-2hr_W0028_H07-210806-140732-66/y.npz", "wb")
f_toa = open("../../data/beamline/Beamline_Cycles-2hr_W0028_H07-210806-140732-66/toa.npz", "wb")
f_tot = open("../../data/beamline/Beamline_Cycles-2hr_W0028_H07-210806-140732-66/tot.npz", "wb")
np.save(f_x, x)
np.save(f_y, y)
np.save(f_toa, toa)
np.save(f_tot, tot)
# Out:
# ../../CSV/Beamline_Cycles-2hr_W0028_H07-210806-140732-66.csv

# %%
# Load Data

f_x = open("../../data/beamline/Beamline_Cycles-2hr_W0028_H07-210806-140732-66/x.npz", "rb")
f_y = open("../../data/beamline/Beamline_Cycles-2hr_W0028_H07-210806-140732-66/y.npz", "rb")
f_toa = open("../../data/beamline/Beamline_Cycles-2hr_W0028_H07-210806-140732-66/toa.npz", "rb")
f_tot = open("../../data/beamline/Beamline_Cycles-2hr_W0028_H07-210806-140732-66/tot.npz", "rb")
x = np.load(f_x)
y = np.load(f_y)
toa = np.load(f_toa)
tot = np.load(f_tot)

# %%
for i in range(0,20):
    print (i, x[i],y[i],toa[i],tot[i])
# Out:
# 0 88 71 6561.435017254688 375
# 1 180 37 6561.435018959375 400
# 2 24 123 6561.435019789063 350
# 3 122 12 6561.435020114063 400
# 4 211 58 6561.435022925 375
# 5 211 59 6561.435022948438 100
# 6 159 139 6561.435023939063 300
# 7 13 213 6561.435024315625 350
# 8 144 43 6561.435024726563 350
# 9 145 43 6561.435024756251 125
# 10 186 149 6561.435024948438 400
# 11 93 149 6561.4350251515625 400
# 12 84 26 6561.435025409375 300
# 13 90 75 6561.435026825 350
# 14 74 161 6561.4350277281255 400
# 15 190 100 6561.435027734376 400
# 16 144 71 6561.435027743751 425
# 17 224 113 6561.435027798438 400
# 18 73 3 6561.435028948438 250
# 19 74 3 6561.435028950001 200

# %%
for i in range(6000000,6000020):
    print (i, x[i],y[i],toa[i],tot[i])
# Out:
# 6000000 181 90 6565.44079058125 450
# 6000001 178 175 6565.44079088125 450
# 6000002 175 204 6565.440791567188 375
# 6000003 85 4 6565.440791575001 450
# 6000004 159 85 6565.4407917234375 250
# 6000005 159 84 6565.440791751563 125
# 6000006 139 72 6565.440791846875 325
# 6000007 210 139 6565.440793379688 350
# 6000008 175 68 6565.440793610938 375
# 6000009 79 230 6565.440793765625 425
# 6000010 204 199 6565.440794767188 375
# 6000011 199 69 6565.44079518125 200
# 6000012 199 70 6565.44079518125 225
# 6000013 147 161 6565.440798903125 275
# 6000014 146 161 6565.440798935938 200
# 6000015 212 36 6565.440799695313 300
# 6000016 139 136 6565.440799785938 325
# 6000017 36 83 6565.4407997906255 375
# 6000018 215 21 6565.440800401563 400
# 6000019 231 12 6565.440801085938 350

# %%
type(x)
# Out:
# numpy.ndarray

# %%
data_length = len(toa)
print(len(toa))
print(max(toa))
print(min(toa))
# Out:
# 62500000
# 6656.948999779688
# 6561.435017254688

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
plt.hist(toa, bins = 400, color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, second',fontsize = 12)
plt.yscale('log')
plt.show()

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
plt.hist(toa, bins = 100, range = (6562.0, 6562.01), color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
plt.hist(toa, bins = 100, range = (6570.0, 6570.01), color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('rate [Hz]',fontsize = 12)
plt.show()

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
plt.hist(toa, bins = 2000, range = (6565.7370, 6565.7371), color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('rate [Hz]',fontsize = 12)
plt.show()

# %%
for i in range(0,20):
    print (i, x[i],y[i],toa[i],tot[i])
# Out:
# 0 88 71 6561.435017254688 375
# 1 180 37 6561.435018959375 400
# 2 24 123 6561.435019789063 350
# 3 122 12 6561.435020114063 400
# 4 211 58 6561.435022925 375
# 5 211 59 6561.435022948438 100
# 6 159 139 6561.435023939063 300
# 7 13 213 6561.435024315625 350
# 8 144 43 6561.435024726563 350
# 9 145 43 6561.435024756251 125
# 10 186 149 6561.435024948438 400
# 11 93 149 6561.4350251515625 400
# 12 84 26 6561.435025409375 300
# 13 90 75 6561.435026825 350
# 14 74 161 6561.4350277281255 400
# 15 190 100 6561.435027734376 400
# 16 144 71 6561.435027743751 425
# 17 224 113 6561.435027798438 400
# 18 73 3 6561.435028948438 250
# 19 74 3 6561.435028950001 200

# %%
threshold = 1e-4
shift = 10.0 # >= 1.0
interval = 20
beam_on = True
last_change_time = 0.0
print('data_length: ', data_length)
boundary = []

for i in range(data_length-interval):
    
    if toa[i] - last_change_time > 4.0:

        if toa[i+interval] - toa[i] > threshold: # beam off
            if beam_on:
                beam_on = False
                threshold = threshold / shift
                last_change_time = toa[i+int(interval/2)]
                boundary += [last_change_time]
                print('Beam off:', last_change_time)

        else: # beam on
            if not beam_on:
                beam_on = True
                threshold = threshold * shift
                last_change_time = toa[i+int(interval/2)]
                boundary += [last_change_time]
                print('Beam on:', last_change_time)

    
print('boundary = ', boundary)
# Out:
# data_length:  62500000
# Beam off: 6565.737042271875
# Beam on: 6573.880854321876
# Beam off: 6578.9056186937505
# Beam on: 6583.909040717188
# Beam off: 6588.933784357813
# Beam on: 6596.378532046875
# Beam off: 6601.404149535938
# Beam on: 6606.909738359375
# Beam off: 6611.935504917188
# Beam on: 6619.569723457813
# Beam off: 6624.5951648656255
# Beam on: 6630.215196739063
# Beam off: 6635.241633651563
# Beam on: 6643.37419878125
# Beam off: 6648.38994431875
# Beam on: 6653.898669829688
# boundary =  [6565.737042271875, 6573.880854321876, 6578.9056186937505, 6583.909040717188, 6588.933784357813, 6596.378532046875, 6601.404149535938, 6606.909738359375, 6611.935504917188, 6619.569723457813, 6624.5951648656255, 6630.215196739063, 6635.241633651563, 6643.37419878125, 6648.38994431875, 6653.898669829688]

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
plt.hist(toa, bins = 400, color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, second',fontsize = 12)
plt.yscale('log')

for b in boundary:
    plt.axvline(x=b,color='blue')
    
plt.show()

# %%
xon1 =[]; yon1 = []; xoff1 = []; yoff1 = []


tminon1 = 4.1; tmaxon1 = 10.0; tminoff1 = 14.5; tmaxoff1 = 20.0

for i in range(len(toa)):
    if (tminon1 < toa[i] < tmaxon1): 
        xon1.append(x[i])
        yon1.append(y[i])
    if (tminoff1 < toa[i] < tmaxoff1): 
        xoff1.append(x[i])
        yoff1.append(y[i])
        
print(len(xon1), len(xoff1))
# Out:
# 7120447 7397207

# %%
fig, (ax0, ax1) = plt.subplots(ncols=2,nrows=1, figsize=(10, 4))

h = ax0.hist2d(xon1, yon1, bins = 256, range = [(0, 256), (0, 256)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax0)

h = ax1.hist2d(xoff1, yoff1, bins = 256, range = [(0, 256), (0, 256)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax1)

fig.tight_layout()
plt.show()

# %%
# Making Image data

#tminon1 = 4.1; tmaxon1 = 10.0; tminoff1 = 14.5; tmaxoff1 = 20.0

x_on1 = []
y_on1 = []
toa_on1 = []
tot_on1 = []

x_off1 = []
y_off1 = []
toa_off1 = []
tot_off1 = []


    
    
for i in range(len(toa)):
    if toa[i] > tminon1 and toa[i] < tmaxon1:
        x_on1.append(x[i])
        y_on1.append(y[i])
        toa_on1.append(toa[i])
        tot_on1.append(tot[i])
        
    if toa[i] > tminoff1 and toa[i] < tmaxoff1:
        x_off1.append(x[i])
        y_off1.append(y[i])
        toa_off1.append(toa[i])
        tot_off1.append(tot[i])

print('on1 length:', len(y_on1), ', off1 length: ', len(y_off1))        
        
img_on1 = np.zeros([256,256])
img_off1 = np.zeros([256,256])


for k in range(len(y_on1)):
    i = x_on1[k]
    j = y_on1[k]
    img_on1[i][j] = img_on1[i][j] + tot_on1[k]    
    
for k in range(len(y_off1)):
    i = x_off1[k]
    j = y_off1[k]
    img_off1[i][j] = img_off1[i][j] + tot_off1[k]
# Out:
# on1 length: 7120447 , off1 length:  7397207

# %%
fig, (ax0, ax1) = plt.subplots(ncols=2,nrows=1, figsize=(10, 10))

h=ax0.imshow(img_on1, norm=mpl.colors.LogNorm())
#fig.colorbar(_)

h=ax1.imshow(img_off1, norm=mpl.colors.LogNorm())
#fig.colorbar(_)
#fig.colorbar(_)

fig.tight_layout()
plt.show()

# %%
img_size_x = 256
img_size_y = 256





on1_sum = np.sum(img_on1)
off1_sum = np.sum(img_off1)



#img_mean = np.mean(img_sum)
#int_mean = np.mean(img_int) # <X>

# %%
ghost11 = np.zeros([img_size_x,img_size_y])
ghost12 = np.zeros([img_size_x,img_size_y])

for i in range(ghost11.shape[0]):
    for j in range(ghost11.shape[1]):

        ghost11[i,j] = on1_sum*img_off1[i,j]
        ghost12[i,j] = off1_sum*img_on1[i,j]

        
        
fig, ax = plt.subplots(ncols=2,nrows=1, figsize=(10, 10))

#h=ax[0].imshow(ghost1, norm=mpl.colors.LogNorm())
h=ax[0].imshow(ghost11)
#fig.colorbar(_)

#h=ax[1].imshow(ghost2, norm=mpl.colors.LogNorm())
h=ax[1].imshow(ghost12)
#fig.colorbar(_)
#fig.colorbar(_)

fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(ncols=1,nrows=1, figsize=(10, 10))
_=ax.imshow(ghost11)
fig.colorbar(_)

# %%
fig, ax = plt.subplots(ncols=1,nrows=1, figsize=(10, 10))
_=ax.imshow(ghost12)
fig.colorbar(_)
