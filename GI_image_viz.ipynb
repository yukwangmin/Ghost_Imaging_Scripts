# %%
import numpy as np
#matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import glob
import time

# %%
f_image1 = open('../../GI-method1.npz', "rb")
image1 = np.load(f_image1)
f_image1.close()

# %%
max(image1.flatten())
# Out:
# 487736532056220.44

# %%
min(image1.flatten())
# Out:
# 0.0

# %%
min(image1[128][:])
# Out:
# 32822649074708.203

# %%
print(image1[128][:] - min(image1[128][:]))
# Out:
# [1.21904243e+14 1.12885935e+14 9.78868650e+13 7.80552521e+13
#  1.05957971e+14 8.21352010e+13 9.18024375e+13 8.26085763e+13
#  7.44153305e+13 1.10277919e+14 1.02065945e+14 8.00959566e+13
#  9.60303709e+13 1.01950313e+14 8.17017563e+13 8.92033735e+13
#  8.10715221e+13 8.56592873e+13 8.87267811e+13 8.33728007e+13
#  8.61231632e+13 8.06662740e+13 8.18480488e+13 9.13884145e+13
#  9.77390941e+13 8.37477805e+13 8.66820705e+13 6.38602395e+13
#  7.27938689e+13 8.53495890e+13 8.38496692e+13 6.51373021e+13
#  7.74732067e+13 8.15417595e+13 8.25660808e+13 6.63849983e+13
#  7.72092933e+13 7.02252274e+13 6.72070219e+13 6.95721567e+13
#  7.36295413e+13 6.95157946e+13 7.31067752e+13 6.48038148e+13
#  7.46160014e+13 7.05056875e+13 7.31805377e+13 6.22772507e+13
#  6.47745731e+13 6.75979641e+13 6.83865865e+13 5.41339019e+13
#  7.02842086e+13 7.53459850e+13 6.48313524e+13 6.63076108e+13
#  6.06399578e+13 7.13527698e+13 7.05105074e+13 6.07476385e+13
# ...

# %%
fig, ax = plt.subplots(ncols=1,nrows=1, figsize=(10, 10))
_=ax.imshow(image1)
fig.colorbar(_)

# %%
fig, ax = plt.subplots(ncols=1,nrows=1, figsize=(10, 10))
_=ax.imshow(image1, norm=mpl.colors.LogNorm())
fig.colorbar(_)

# %%
fig, ax = plt.subplots(ncols=1,nrows=1, figsize=(10, 10))
_=ax.imshow(image1, norm=mpl.colors.NoNorm())
fig.colorbar(_)

# %%
fig, ax = plt.subplots(ncols=1,nrows=1, figsize=(10, 10))
_=ax.imshow(image1, norm=mpl.colors.Normalize())
fig.colorbar(_)

# %%
fig, ax = plt.subplots(ncols=1,nrows=1, figsize=(10, 10))
_=ax.imshow(image1, norm=mpl.colors.PowerNorm(2))
fig.colorbar(_)

# %%
fig, ax = plt.subplots(ncols=1,nrows=1, figsize=(10, 10))
_=ax.imshow(image1, norm=mpl.colors.SymLogNorm(1))
fig.colorbar(_)

# %%
fig, ax = plt.subplots(ncols=1,nrows=1, figsize=(10, 10))
_=ax.imshow(image1, norm=mpl.colors.NoNorm())
fig.colorbar(_)

# %%
fig, ax = plt.subplots(ncols=1,nrows=1, figsize=(10, 10))
_=ax.imshow(image1, norm=mpl.colors.NoNorm())
fig.colorbar(_)
